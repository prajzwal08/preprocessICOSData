# %%
from terracatalogueclient import Catalogue
from terracatalogueclient.config import CatalogueConfig, CatalogueEnvironment


config = CatalogueConfig.from_environment(CatalogueEnvironment.CGLS)
catalogue = Catalogue(config)

# %%
catalogue = Catalogue()

# %%
collections = catalogue.get_collections()
for c in collections:
    print(f"{c.id} - {c.properties['title']}")
# Out:
# ---------------------------------------------------------------------------
# TimeoutOccurred                           Traceback (most recent call last)
# Cell In[11], line 2
#       1 collections = catalogue.get_collections()
# ----> 2 for c in collections:
#       3     print(f"{c.id} - {c.properties['title']}")
#
# File ~/.local/lib/python3.8/site-packages/terracatalogueclient/client.py:581, in Catalogue._get_paginated_feature_generator(self, url, url_params, builder)
#     578 limit = url_params.pop("limit", None)
#     579 feature_count = 0
# --> 581 response = self._session_search.get(url, params=url_params, timeout=_SEARCH_TIMEOUT)
#     582 logger.debug(f"{response.request.url} - {response.status_code}")
#     584 if response.status_code == requests.codes.ok:
#
# File ~/.local/lib/python3.8/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/requests/sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     562 # Create the Request.
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)
#     573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#     579 settings = self.merge_environment_settings(
#     580     prep.url, proxies, stream, verify, cert
#     581 )
#
# File ~/.local/lib/python3.8/site-packages/requests/sessions.py:486, in Session.prepare_request(self, request)
#     483     auth = get_netrc_auth(request.url)
#     485 p = PreparedRequest()
# --> 486 p.prepare(
#     487     method=request.method.upper(),
#     488     url=request.url,
#     489     files=request.files,
#     490     data=request.data,
#     491     json=request.json,
#     492     headers=merge_setting(
#     493         request.headers, self.headers, dict_class=CaseInsensitiveDict
#     494     ),
#     495     params=merge_setting(request.params, self.params),
#     496     auth=merge_setting(auth, self.auth),
#     497     cookies=merged_cookies,
#     498     hooks=merge_hooks(request.hooks, self.hooks),
#     499 )
#     500 return p
#
# File ~/.local/lib/python3.8/site-packages/requests/models.py:372, in PreparedRequest.prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     370 self.prepare_cookies(cookies)
#     371 self.prepare_body(data, files, json)
# --> 372 self.prepare_auth(auth, url)
#     374 # Note that prepare_auth must be last to enable authentication schemes
#     375 # such as OAuth to work on a fully prepared request.
#     376
#     377 # This MUST go after prepare_auth. Authenticators could add a hook
#     378 self.prepare_hooks(hooks)
#
# File ~/.local/lib/python3.8/site-packages/requests/models.py:603, in PreparedRequest.prepare_auth(self, auth, url)
#     600     auth = HTTPBasicAuth(*auth)
#     602 # Allow auth to make its changes.
# --> 603 r = auth(self)
#     605 # Update self to reflect the auth changes.
#     606 self.__dict__.update(r.__dict__)
#
# File ~/.local/lib/python3.8/site-packages/requests_auth/authentication.py:629, in OAuth2AuthorizationCodePKCE.__call__(self, r)
#     628 def __call__(self, r):
# --> 629     token = OAuth2.token_cache.get_token(
#     630         key=self.state,
#     631         early_expiry=self.early_expiry,
#     632         on_missing_token=self.request_new_token,
#     633         on_expired_token=self.refresh_token,
#     634     )
#     635     r.headers[self.header_name] = self.header_value.format(token=token)
#     636     return r
#
# File ~/.local/lib/python3.8/site-packages/requests_auth/oauth2_tokens.py:165, in TokenMemoryCache.get_token(self, key, early_expiry, on_missing_token, on_expired_token, **on_missing_token_kwargs)
#     163 if on_missing_token is not None:
#     164     with self.forbid_concurrent_missing_token_function_call:
# --> 165         new_token = on_missing_token(**on_missing_token_kwargs)
#     166         if len(new_token) == 2:  # Bearer token
#     167             state, token = new_token
#
# File ~/.local/lib/python3.8/site-packages/requests_auth/authentication.py:640, in OAuth2AuthorizationCodePKCE.request_new_token(self)
#     638 def request_new_token(self) -> tuple:
#     639     # Request code
# --> 640     state, code = oauth2_authentication_responses_server.request_new_grant(
#     641         self.code_grant_details
#     642     )
#     644     # As described in https://tools.ietf.org/html/rfc6749#section-4.1.3
#     645     self.token_data["code"] = code
#
# File ~/.local/lib/python3.8/site-packages/requests_auth/oauth2_authentication_responses_server.py:191, in request_new_grant(grant_details)
#     189 with FixedHttpServer(grant_details) as server:
#     190     _open_url(grant_details.url)
# --> 191     return _wait_for_grant(server)
#
# File ~/.local/lib/python3.8/site-packages/requests_auth/oauth2_authentication_responses_server.py:223, in _wait_for_grant(server)
#     221 logger.debug("Waiting for user authentication...")
#     222 while not server.grant:
# --> 223     server.handle_request()
#     224     server.ensure_no_error_occurred()
#     225 return server.grant
#
# File /usr/lib/python3.8/socketserver.py:301, in BaseServer.handle_request(self)
#     299 timeout = deadline - time()
#     300 if timeout < 0:
# --> 301     return self.handle_timeout()
#
# File ~/.local/lib/python3.8/site-packages/requests_auth/oauth2_authentication_responses_server.py:175, in FixedHttpServer.handle_timeout(self)
#     174 def handle_timeout(self):
# --> 175     raise TimeoutOccurred(self.timeout)
#
# TimeoutOccurred: User authentication was not received within 60.0 seconds.
